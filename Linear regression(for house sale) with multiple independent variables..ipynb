# %%
#Importing libraries

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
plt.style.use('dark_background')
import warnings
warnings.filterwarnings(action='ignore')

# %%
import numpy as np
import statsmodels.api as sm
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
plt.style.use(['seaborn-dark-palette','dark_background'])

# %%
#read csv file
df=pd.read_csv(r'C:\Users\pc\Documents\python internshala\Module 4 assignment\Transformed_Housing_Data2.csv')

# %%
df.shape
# Out:
# (21609, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21609 entries, 0 to 21608
# Data columns (total 31 columns):
# Sale_Price                                   21609 non-null float64
# No of Bedrooms                               21609 non-null int64
# No of Bathrooms                              21609 non-null float64
# Flat Area (in Sqft)                          21609 non-null float64
# Lot Area (in Sqft)                           21609 non-null float64
# No of Floors                                 21609 non-null float64
# No of Times Visited                          21609 non-null int64
# Overall Grade                                21609 non-null int64
# Area of the House from Basement (in Sqft)    21609 non-null float64
# Basement Area (in Sqft)                      21609 non-null int64
# Age of House (in Years)                      21609 non-null int64
# Latitude                                     21609 non-null float64
# ...

# %%
df.head()
# Out:
#    Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors  No of Times Visited  Overall Grade  \
# 0              5650.0           1.0                    0              7
# 1              7242.0           2.0                    0              7
# 2             10000.0           1.0                    0              6
# 3              5000.0           1.0                    0              7
# 4              8080.0           1.0                    0              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  ...  \
# ...

# %% [markdown]
# # Scaling Dataset

# %%
# scaling
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

## seperating target variable and scaling independent variables and storing them back to the dataframe.

Y=df['Sale_Price']
X=scaler.fit_transform(df.drop(columns=['Sale_Price']))
X=pd.DataFrame(data=X, columns=df.drop(columns=['Sale_Price']).columns)
X.head()
# Out:
#    No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  \
# 0       -0.398724        -1.447526            -0.979905           -0.228291
# 1       -0.398724         0.175684             0.533718           -0.189858
# 2       -1.474115        -1.447526            -1.426369           -0.123276
# 3        0.676667         1.149611            -0.130534           -0.243983
# 4       -0.398724        -0.148958            -0.435436           -0.169628
#
#    No of Floors  No of Times Visited  Overall Grade  \
# 0     -0.915389             -0.30579      -0.563993
# 1      0.936817             -0.30579      -0.563993
# 2     -0.915389             -0.30579      -1.468566
# 3     -0.915389             -0.30579      -0.563993
# 4     -0.915389             -0.30579       0.340581
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  \
# 0                                  -0.734722                -0.658697
# ...

# %% [markdown]
# # Checking & Removing Multicollinearity

# %%
#Checking corr among all independent var.

X.corr()
# Out:
#                                            No of Bedrooms  No of Bathrooms  \
# No of Bedrooms                                   1.000000         0.515813
# No of Bathrooms                                  0.515813         1.000000
# Flat Area (in Sqft)                              0.576628         0.754568
# Lot Area (in Sqft)                               0.031692         0.087732
# No of Floors                                     0.175536         0.500776
# No of Times Visited                              0.079575         0.187791
# Overall Grade                                    0.349223         0.635638
# Area of the House from Basement (in Sqft)        0.477549         0.685088
# Basement Area (in Sqft)                          0.303294         0.283798
# Age of House (in Years)                         -0.154113        -0.505954
# Latitude                                        -0.008708         0.024570
# ...

# %% [markdown]
# Total=900 corr pairs, very tedious task to identify & remove, so we set a corr. threshold limit(0.5) so pair with corr. greater than this  will be removed.

# %%
#Pair of I.V with Corr>0.5

#storing the results in var 'k'
k=X.corr()

#List comprehension=allows us to write simple loops&nested loops to form a list in a single line.

z=[[str(i), str(j)] for i in k.columns for j in k.columns if (k.loc[i,j] >abs(0.5))& (i!=j)]
z, len(z)
# Out:
# ([['No of Bedrooms', 'No of Bathrooms'],
#   ['No of Bedrooms', 'Flat Area (in Sqft)'],
#   ['No of Bathrooms', 'No of Bedrooms'],
#   ['No of Bathrooms', 'Flat Area (in Sqft)'],
#   ['No of Bathrooms', 'No of Floors'],
#   ['No of Bathrooms', 'Overall Grade'],
#   ['No of Bathrooms', 'Area of the House from Basement (in Sqft)'],
#   ['No of Bathrooms', 'Living Area after Renovation (in Sqft)'],
#   ['Flat Area (in Sqft)', 'No of Bedrooms'],
#   ['Flat Area (in Sqft)', 'No of Bathrooms'],
#   ['Flat Area (in Sqft)', 'Overall Grade'],
#   ['Flat Area (in Sqft)', 'Area of the House from Basement (in Sqft)'],
#   ['Flat Area (in Sqft)', 'Living Area after Renovation (in Sqft)'],
#   ['Lot Area (in Sqft)', 'Lot Area after Renovation (in Sqft)'],
#   ['No of Floors', 'No of Bathrooms'],
#   ['No of Floors', 'Area of the House from Basement (in Sqft)'],
#   ['Overall Grade', 'No of Bathrooms'],
#   ['Overall Grade', 'Flat Area (in Sqft)'],
# ...

# %% [markdown]
# Total=32, means 16 Pairs are unique here becaiuse of same corr for i,j & j,i.

# %% [markdown]
# # #VIF

# %%
# Removing variables with multicollinearity by VIF.
#Calculating VIF
#importing variance_inflation_factor function from Statsmodels.

from statsmodels.stats.outliers_influence import variance_inflation_factor

vif_df = X

#Calculating VIF for every I.V column.

VIF = pd.Series([variance_inflation_factor(vif_df.values,i) for i in range (vif_df.shape[1])], index=vif_df.columns)
VIF
# Out:
# No of Bedrooms                                  1.639470
# No of Bathrooms                                 3.374992
# Flat Area (in Sqft)                          1481.681648
# Lot Area (in Sqft)                              2.108079
# No of Floors                                    2.127787
# No of Times Visited                             1.432385
# Overall Grade                                   2.967448
# Area of the House from Basement (in Sqft)    1205.549115
# Basement Area (in Sqft)                       345.465009
# Age of House (in Years)                         2.629539
# Latitude                                        2.471442
# Longitude                                       1.672691
# Living Area after Renovation (in Sqft)          3.068139
# Lot Area after Renovation (in Sqft)             2.144347
# Years Since Renovation                          2.788098
# Condition_of_the_House_Excellent               53.578111
# ...

# %% [markdown]
# Remove variables having VIF>5 above. We have total 7 such variables.

# %%
#Checking the index where max value of VIF is stored.

VIF[VIF== VIF.max()].index[0]
# Out:
# 'Flat Area (in Sqft)'

# %%
#Remove this index having max VIF.

def MC_remover(df):
    vif=pd.Series([variance_inflation_factor(df.values, i)for i in range (df.shape[1])], index=df.columns)
    if vif.max () >5:
        print(vif[vif==vif.max()].index[0], 'has been removed')
        df=df.drop(columns=[vif[vif==vif.max()].index[0]])
        return df
    else:
        print('no multicollinearity present anymore')
        return df

# %%
#Estimated above 7 I.V causing multicollinearity should be removed.

for i in range(7):
    vif_df=MC_remover(vif_df)
# Out:
# Flat Area (in Sqft) has been removed
# Condition_of_the_House_Fair has been removed
# no multicollinearity present anymore
# no multicollinearity present anymore
# no multicollinearity present anymore
# no multicollinearity present anymore
# no multicollinearity present anymore

# %%
vif_df.head()
# Out:
#    No of Bedrooms  No of Bathrooms  Lot Area (in Sqft)  No of Floors  \
# 0       -0.398724        -1.447526           -0.228291     -0.915389
# 1       -0.398724         0.175684           -0.189858      0.936817
# 2       -1.474115        -1.447526           -0.123276     -0.915389
# 3        0.676667         1.149611           -0.243983     -0.915389
# 4       -0.398724        -0.148958           -0.169628     -0.915389
#
#    No of Times Visited  Overall Grade  \
# 0             -0.30579      -0.563993
# 1             -0.30579      -0.563993
# 2             -0.30579      -1.468566
# 3             -0.30579      -0.563993
# 4             -0.30579       0.340581
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  \
# 0                                  -0.734722                -0.658697
# 1                                   0.460990                 0.245134
# 2                                  -1.229916                -0.658697
# ...

# %% [markdown]
# Flat_area has been removed and no multicollineartiy is present with VIF>5

# %% [markdown]
# # # # VIF for remaining columns

# %%
#After removal of var check whether multicollinearity still exists or not in other columns.
VIF = pd.Series([variance_inflation_factor(vif_df.values,i) for i in range (vif_df.shape[1])], index=vif_df.columns)
VIF, len(vif_df.columns)
# Out:
# (No of Bedrooms                               1.638990
#  No of Bathrooms                              3.373805
#  Lot Area (in Sqft)                           2.107495
#  No of Floors                                 2.127703
#  No of Times Visited                          1.432363
#  Overall Grade                                2.956967
#  Area of the House from Basement (in Sqft)    4.580042
#  Basement Area (in Sqft)                      1.974981
#  Age of House (in Years)                      2.626504
#  Latitude                                     2.471343
#  Longitude                                    1.672667
#  Living Area after Renovation (in Sqft)       3.063886
#  Lot Area after Renovation (in Sqft)          2.144068
#  Years Since Renovation                       2.788064
#  Condition_of_the_House_Excellent             1.206487
#  Condition_of_the_House_Good                  1.251488
#  Condition_of_the_House_Okay                  1.025386
# ...

# %% [markdown]
# No variable have VIF>5, so multicollinearity has been removed.

# %% [markdown]
# # # Creating Train/Test set

# %%
#define i/p and o/p variables.
#replace X with new vif_data(without multicollinearity)
X=vif_df
Y=df['Sale_Price']

# %%
#using sklearn split train and test set.

from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=101 )

X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((15126, 28), (6483, 28), (15126,), (6483,))

# %% [markdown]
# # #Implementing LinearRegression model from sklearn

# %%
#sklearn will allow us to create few lines of code.
#No need to define our own Gradient descent.

from sklearn.linear_model import LinearRegression
lr=LinearRegression(normalize=True)
lr.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
#Checking all coefficient of I.V calculated by LinearRegression.
lr.coef_
# Out:
# array([ -3928.66247639,  12028.44560689,  14967.00497585,   2697.55278605,
#         27220.31313417,  59965.44665815,  80697.80906997,  27729.56715434,
#         27873.90231343,  21397.40341959, -23854.32640243,  17943.26729788,
#         -2896.98542901, -10179.085198  ,  14239.3533334 ,   5095.97603571,
#         -2296.64888137,  14594.33847962,  10761.77007875,  12165.83372082,
#         33842.29544383,  63269.82875283,  81086.08553213,  50718.63947886,
#         73274.09568028,  40153.03595158,  67405.70271285,  22113.74944051])

# %%
#Generate predictions over test set
predictions=lr.predict(X_test)
lr.score(X_test, Y_test)
# Out:
# 0.8461987715586199

# %% [markdown]
# This is R2 value (84%) , quiet good for fit line prediction in regression model.

# %% [markdown]
# # #Verifying assumptions for lin reg by using Residual plot

# %%
#Residual plot to visualize and check HOMOSDASTICITY of error terms.

residuals=predictions-Y_test
residual_table=pd.DataFrame({'residuals':residuals,
                            'predictions':predictions})
residual_table = residual_table.sort_values(by='predictions')

# %%
#Creating lists to store max prediction
z= [i for i in range(int(residual_table['predictions'].max()))]
k= [0 for i in range(int(residual_table['predictions'].max()))]

# %%
plt.figure(figsize=(8,3), dpi=130)

plt.scatter(x=residual_table['predictions'], y=residual_table['residuals'], color='green', s=2)
plt.plot(z, k, color='red', linewidth=3, label='regression line')

plt.ylim(-800000, 800000)
plt.xlabel('fitted points (ordered by predictions)')
plt.ylabel('residuals')
plt.title('residual plot')
plt.legend()
plt.show()

# %% [markdown]
# There is no pipe or cone shape residual plot we obtained, so we will improve data points. Few +ve outliers are also present in above plot.

# %% [markdown]
# Most of the residuals are densly populated around 200000 to -200000 range, there is high probability of normal distribution of residuals.

# %%
#Check error term(residuals) distrubution.

plt.figure(figsize=(10,8), dpi=100)
plt.hist(residual_table['residuals'], color='green', bins=200)
plt.xlabel('residuals')
plt.ylabel('frequency')
plt.title('distribution of residuals')
plt.show()

# %% [markdown]
# Above curve is showing Normal Distribution of error terms which is a required assumption for linear regression.

# %% [markdown]
# ## Visualizing coefficients to interpret model results

# %%
coefficients_table=pd.DataFrame({'column': X_train.columns,
                               'coefficients': lr.coef_})
coefficient_table=coefficients_table.sort_values(by='coefficients')

# %%
plt.figure(figsize=(8, 6), dpi=120)
x=coefficient_table['column']
y=coefficient_table['coefficients']
#plot horizontal bars.
plt.barh(x,y)
plt.xlabel('coefficients')
plt.ylabel('variables')
plt.title('normalized coefficient plot')
plt.show()

# %% [markdown]
# Varibles are in descending order of their role in assigning sale price of the house.

# %% [markdown]
# # Adjusted R2

# %%
#Forward feature selection
def adj_r2 (df_X, df_Y, predictions):
    from sklearn.metrics import r2_score 
    R= r2_score (df_Y, predictions)
    n=len(df_Y)
    m=len(df_X.columns)
    adj_R=1- ((1-R)*(n-1))/(n-m-1)
    return adj_R

# %%
adj_r2(X_test, Y_test, predictions)
# Out:
# 0.8455315211098503

# %% [markdown]
# Compare it with R2..Adj_r2(0.8455) < R2(0.8461) it means there are some variables which are not adding value to the final model.

# %%
def return_r2 (X, Y, model):
    model.fit(X, Y)
    pred= model.predict(X)
    m=len(X.columns)
    r2=adj_r2(m, Y, pred)
    return r2

# %%
def forward_selection (model, X, Y, max_features):
    '''max_features= select best feature upto max_features value
    
    returns 
    Rmax= Adjusted R2 of the final model
    history= list of Rmax at every new I.V  added to the model
    X[f_col]=best features upto max_features'''
    
    f_col=[]
    history=[]
    
    for i in range (max_features):
        f_col.append('blank')
        temp=f_col[:]
        Rmax=-1
        
        for var in X.columns:
            temp[-1]=var
            r2=return_r2(X[temp], Y, model)
            if r2>=Rmax:
                Rmax=r2
                f_Col[-1]=var
                elim=var
                
        print ("selected", f_col[-1], "with new r2=", Rmax)
        history.append(Rmax)
        
    return Rmax, history, X[f_col]

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression(normalize=True)
score, history, sel_data = forward_selection(lr, X_train, Y_train, 5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-db4fe8be0b45> in <module>
#       1 from sklearn.linear_model import LinearRegression
#       2 lr=LinearRegression(normalize=True)
# ----> 3 score, history, sel_data = forward_selection(lr, X_train, Y_train, 5)
#
# <ipython-input-46-48212fb122ce> in forward_selection(model, X, Y, max_features)
#      17         for var in X.columns:
#      18             temp[-1]=var
# ---> 19             r2=return_r2(X[temp], Y, model)
#      20             if r2>=Rmax:
#      21                 Rmax=r2
#
# <ipython-input-45-7eb1e7bb1310> in return_r2(X, Y, model)
#       3     pred= model.predict(X)
#       4     m=len(X.columns)
# ----> 5     r2=adj_r2(m, Y, pred)
#       6     return r2
#       7
#
# <ipython-input-34-5bebbb1fcffc> in adj_r2(df_X, df_Y, predictions)
#       4     R= r2_score (df_Y, predictions)
# ...

# %% [markdown]
# ## Backward elimination

# %%
def backward_elimination (model, X, Y, min_features):
    elim_data= X[:]
    r2_history=[]
    base_r2=return_r2(elim_data, Y, model)
    print("base _r2 is", base_r2)
    
    for i in range (X.shape[1]-min_features):
        difference = -100
        for var in elim_data.columns:
            temp=elim_data.drop(columns-[var])
            r2= return_r2 (temp, Y, model)
            
            if (r2-base_r2) > difference:
                difference= r2-base_r2
                eliminate= var
                new_r2=r2
            
        elim_data.drop(columns=[eliminate], inplace=True)
        r2_history.append(new_r2)
        
        print(eliminate, "Eliminated: New adj_r2=", new_r2,)
        base_r2=new_r2
    
    return base_r2, r2_history, elim_data

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression(normalize=True)
score, history, survived_data = backward_elimination(lr, X_train, Y_train, 15)
base_r2 is 0.8411713183817104
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-aa172eb2a1d6> in <module>
#       1 from sklearn.linear_model import LinearRegression
#       2 lr=LinearRegression(normalize=True)
# ----> 3 score, history, survived_data = backward_elimination(lr, X_train, Y_train, 15)
#       4 base_r2 is 0.8411713183817104
#
# <ipython-input-53-3523ca77e417> in backward_elimination(model, X, Y, min_features)
#       2     elim_data= X[:]
#       3     r2_history=[]
# ----> 4     base_r2=return_r2(elim_data, Y, model)
#       5     print("base _r2 is", base_r2)
#       6
#
# <ipython-input-48-7eb1e7bb1310> in return_r2(X, Y, model)
#       3     pred= model.predict(X)
#       4     m=len(X.columns)
# ----> 5     r2=adj_r2(m, Y, pred)
#       6     return r2
#       7
#
# <ipython-input-34-5bebbb1fcffc> in adj_r2(df_X, df_Y, predictions)
# ...

# %%
plt.figure(figsize=(5,5), dpi=100)
plt.plot(range(len(history),0, -1), history, color='red')
plt.xlabel('remaining features')
plt.ylabel('adj_R2 Score')
#plt .ytricks([z/100 for z in range ()])

plt.title('Backward Elimination')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-78510d979e67> in <module>
#       1 plt.figure(figsize=(5,5), dpi=100)
# ----> 2 plt.plot(range(len(history),0, -1), history, color='red')
#       3 plt.xlabel('remaining features')
#       4 plt.ylabel('adj_R2 Score')
#       5 #plt .ytricks([z/100 for z in range ()])
#
# NameError: name 'history' is not defined
